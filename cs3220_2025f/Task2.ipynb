# %%
from pyvis.network import Network 
import streamlit as st
from src.TreasureMap import *
from src.graphClass import Graph
from src.TreasureMapEnv import TreasureMapEnv
from src.TreasureMapproblem import *

# %%
GraphData = {'Room1': {'Room2': 1},
             'Room2': {'Room3': 1},
             'Room3': {'Room4': 1},
             'Room4': {'Room5': 1, 'Room6': 1},
             'Room6': {'Room7': 1, 'Room27': 1},
             'Room7': {'Room8': 1, 'Room20': 1},
             'Room8': {'Room9': 1, 'Room11': 1},
             'Room9': {'Room10': 1},
             'Room11': {'Room12': 1},
             'Room12': {'Room13': 1},
             'Room13': {'Room14': 1},
             'Room14': {'Room15': 1},
             'Room15': {'Room16': 1, 'Room18': 1},
             'Room18': {'Room17': 1, 'Room19': 1},
             'Room20': {'Room21': 1},
             'Room21': {'Room22': 1},
             'Room22': {'Room23': 1},
             'Room23': {'Room24': 1},
             'Room24': {'Room25': 1},
             'Room25': {'Room26': 1},
             'Room27': {'Room28': 1},
             'Room28': {'Room29': 1, 'Room37': 1},
             'Room29': {'Room30': 1},
             'Room30': {'Room31': 1},
             'Room31': {'Room32': 1},
             'Room32': {'Room33': 1},
             'Room33': {'Room34': 1},
             'Room34': {'Room35': 1},
             'Room35': {'Room36': 1},
             'Room37': {'Room38': 1},
             'Room38': {'Room39': 1},
             'Room39': {'Room40': 1, 'Room43': 1},
             'Room40': {'Room41': 1, 'Room42': 1},
             'Room43': {'Room44': 1},
             'Room44': {'Room45': 1, 'Room46': 1},
             'Room46': {'Room47': 1},
             'Room47': {'Room48': 1}}


initial_state = 'Room1' 
goal = 'Room48'

# %%
Map = TreasureMapEnv.Map(GraphData)
Problem = TreasureMapProblem('Room1', 'Room48')

# %%
Solve = TreasureMap('Room1', GraphData, 'Room48', BestFirstSearchAgentProgram)

# %%
Solve.run()
# Out:
# goal list: Room48
# I have the only goal = Room48
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 Solve.run()
#
# File c:\Users\conno_52qz545\CS3220 Task2 Backup\Lab3\cs3220_2025f\src\TreasureMap.py:85, in TreasureMap.run(self)
#      83 else:
#      84   print ("I have the only goal = {}". format(self.goal))
# ---> 85   return super().__call__(self.state)
#
# File c:\Users\conno_52qz545\CS3220 Task2 Backup\Lab3\cs3220_2025f\src\problemSolvingAgentProgramClass.py:38, in SimpleProblemSolvingAgentProgram.__call__(self, percept, curGoal)
#      36 else:
#      37       problem = self.formulate_problem(self.state, goal)
# ---> 38       self.seq = self.search(problem)
#      42 if not self.seq:
#      43     return None
#
# File c:\Users\conno_52qz545\CS3220 Task2 Backup\Lab3\cs3220_2025f\src\TreasureMap.py:53, in TreasureMap.search(self, problem)
# ...
