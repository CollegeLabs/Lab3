# %%
from pyvis.network import Network 
import streamlit as st
from src.TreasureMap import *
from src.graphClass import Graph
from src.TreasureMapEnv import TreasureMapEnv
from src.TreasureMapproblem import *
from data.TreasureMapData import *
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 7
#       5 from src.TreasureMapEnv import TreasureMapEnv
#       6 from src.TreasureMapproblem import *
# ----> 7 from data.TreasureMapData import *
#
# File c:\Users\conno_52qz545\CS3220 Task2 Backup\Lab3\cs3220_2025f\data\TreasureMapData.py:98
#      46 Locations = dict(
#      47 Room1 = (0,0),
#      48 Room2 = (0,1),
#    (...)     93 Room47 = (7,6),
#      94 Room48 = (7,7))
#      96 Locvalue=[0,1,2,3,4,5,6,7]
# ---> 98 room1=''.join(map(lambda x: x[0],(Locvalue[0],Locvalue[0]))),
#      99 room2=''.join(map(lambda x: x[0],(Locvalue[0],Locvalue[1]))),
#     100 room3=''.join(map(lambda x: x[0],(Locvalue[0],Locvalue[2]))),
#
# File c:\Users\conno_52qz545\CS3220 Task2 Backup\Lab3\cs3220_2025f\data\TreasureMapData.py:98, in <lambda>(x)
#      46 Locations = dict(
#      47 Room1 = (0,0),
# ...

# %%
initial_state = 'Room1' 
goal = 'Room48'

# %%
Map = TreasureMapEnv.Map(GraphData)
Problem = TreasureMapProblem('Room1', 'Room48', GraphData)
Graph = TreasureMapGraph(TreasureMap,Locations)

#Map.origin

# %%
Solve = TreasureMap(initial_state, GraphData, goal, BestFirstSearchAgentProgram)

# %%
Solve.formulate_problem(Solve.state,Solve.goal)

# %%
BFSAP = BestFirstSearchAgentProgram()
seq = BFSAP(Problem)
