# %%
from pyvis.network import Network 
import streamlit as st
from src.TreasureMap import *
from src.graphClass import *
from src.TreasureMapEnv import TreasureMapEnv
from src.TreasureMapGraph import *
from src.TreasureMapproblem import *
from data.TreasureMapData import *
from src.agents import *
from src.Treasures import *

# %%
initial_state = 'Room1' 
goal = 'Room48'

# %%
Map = TreasureMapGraph.Map(GraphData)
G = TreasureMapGraph(GraphData)
Problem = TreasureMapProblem('Room1', 'Room48', Graph)
Env = TreasureMapEnv(G)

Problem.initial
# Out:
# 'Room1'

# %%
BFSAP = ProblemSolvingNavAgentBFS(initial_state,G,goal)
BFSAP.formulate_goal(BFSAP.state)
BFSAP.run()
# Out:
# goal list: Room48
# I have the only goal = Room48
# <Node Room1>
# <Node Room2>
# <Node Room3>
# <Node Room4>
# <Node Room5>
# <Node Room6>
# <Node Room27>
# <Node Room28>
# <Node Room29>
# <Node Room30>
# <Node Room31>
# <Node Room32>
# <Node Room33>
# <Node Room34>
# <Node Room35>
# <Node Room36>
# <Node Room37>
# <Node Room38>
# <Node Room39>
# <Node Room40>
# <Node Room41>
# <Node Room42>
# <Node Room43>
# <Node Room44>
# <Node Room45>
# <Node Room46>
# <Node Room47>
# <Node Room48>
# Solution (a sequence of actions) from the initial state to a goal: ['Room2', 'Room3', 'Room4', 'Room6', 'Room27', 'Room28', 'Room37', 'Room38', 'Room39', 'Room43', 'Room44', 'Room46', 'Room47', 'Room48']

# %%
Env.add_thing(BFSAP)
# Out:
# I have already don my work. Find someone else
# The Agent in Room1 with performance 48

# %%
Env.run()
#rn performance is being grabbed from navproblemsolvingagent
# Out:
# step 1:
# Agent decided to move to Room2.
# Agent in Room2 with performance = 47
# step 2:
# Agent decided to move to Room3.
# Agent in Room3 with performance = 46
# step 3:
# Agent decided to move to Room4.
# Agent in Room4 with performance = 45
# step 4:
# Agent decided to move to Room6.
# Agent in Room6 with performance = 44
# step 5:
# Agent decided to move to Room27.
# Agent in Room27 with performance = 43
# step 6:
# Agent decided to move to Room28.
# Agent in Room28 with performance = 42
# step 7:
# Agent decided to move to Room37.
# Agent in Room37 with performance = 41
# step 8:
# Agent decided to move to Room38.
# Agent in Room38 with performance = 40
# step 9:
# Agent decided to move to Room39.
# Agent in Room39 with performance = 39
# step 10:
# Agent decided to move to Room43.
# Agent in Room43 with performance = 38

# %%
Env2 = TreasureMapEnv(G)

Pile_of_Gold = Gold()
Diamond = D()
flyer_for_100_free_pizzas = Pizza()
twenty_extra_point_for_cs3220_final_exam = CSPoints()

Env2.add_treasure(Pile_of_Gold)
Env2.add_treasure(Diamond)
Env2.add_treasure(flyer_for_100_free_pizzas)
Env2.add_treasure(twenty_extra_point_for_cs3220_final_exam)

T = random.choice([Pile_of_Gold, Diamond, flyer_for_100_free_pizzas, twenty_extra_point_for_cs3220_final_exam])
#Twogoals = [T, 'room48']
Twogoals = 'room48'
TL = T.location
TM = T.name

BFSAP2 = ProblemSolvingNavAgentBFS(initial_state,G,Twogoals)
BFSAP2.formulate_goal(BFSAP2.state)
BFSAP2.run()
# Out:
# goal list: Room48
# I have the only goal = Room48
# <Node Room1>
# <Node Room2>
# <Node Room3>
# <Node Room4>
# <Node Room5>
# <Node Room6>
# <Node Room27>
# <Node Room28>
# <Node Room29>
# <Node Room30>
# <Node Room31>
# <Node Room32>
# <Node Room33>
# <Node Room34>
# <Node Room35>
# <Node Room36>
# <Node Room37>
# <Node Room38>
# <Node Room39>
# <Node Room40>
# <Node Room41>
# <Node Room42>
# <Node Room43>
# <Node Room44>
# <Node Room45>
# <Node Room46>
# <Node Room47>
# <Node Room48>
# Solution (a sequence of actions) from the initial state to a goal: ['Room2', 'Room3', 'Room4', 'Room6', 'Room27', 'Room28', 'Room37', 'Room38', 'Room39', 'Room43', 'Room44', 'Room46', 'Room47', 'Room48']

# %%
#Env2.add_thing(BFSAP2)
